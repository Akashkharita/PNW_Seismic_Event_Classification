# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from glob import glob
import pickle

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# ## Comparing Classic ML models on a common validation dataset

# %%
filename1 = 'P_10_30_F_1_10_50'
filename2 = 'P_10_30_F_05_15_50'

filename3 = 'P_10_100_F_1_10_50'
filename4 = 'P_10_100_F_05_15_50'

filename5 = 'P_50_100_F_1_10_50'
filename6 = 'P_50_100_F_05_15_50'




## scatnet results
# Save to a file
with open('../results/balanced_trace_report_scat_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_10_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model4 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model5 = pickle.load(pickle_file)
        
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_50_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model6 = pickle.load(pickle_file)
        
        
        
        
        
        
        
        
## scatnet results
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model1 = pickle.load(pickle_file)
        
        
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_10_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model5 = pickle.load(pickle_file)     

# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_50_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model6 = pickle.load(pickle_file)
        
        
                  


## Physical results        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model1 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model2 = pickle.load(pickle_file)      
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model3 = pickle.load(pickle_file)
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model4 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model6 = pickle.load(pickle_file)
 


        
## Physical+Manual results        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model1 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model2 = pickle.load(pickle_file)      
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model3 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model5 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model6 = pickle.load(pickle_file)
        
        
        
        
        
## Tsfel results
# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model6 = pickle.load(pickle_file)
     
    
    
    
    
    
    
## Tsfel + Man results
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model4 = pickle.load(pickle_file)    
        
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model6 = pickle.load(pickle_file)      
        
    
    
    
    
        
## Tsfel + Physical results
with open('../results/balanced_trace_report_phy_tsf_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model1 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model2 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model3 = pickle.load(pickle_file)

with open('../results/balanced_trace_report_phy_tsf_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model4 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model5 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model6 = pickle.load(pickle_file)
        
        
        
## Tsfel + Physical + Manual
with open('../results/balanced_trace_report_phy_tsf_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model1 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model2 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model3 = pickle.load(pickle_file)

with open('../results/balanced_trace_report_phy_tsf_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model4 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model5 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model6 = pickle.load(pickle_file)
        
        
## Deep Learning
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_mycnn_1d.pkl', 'rb') as pickle_file:
     trace_report_mycnn_1d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_seismiccnn_2d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_2d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_mycnn_2d.pkl', 'rb') as pickle_file:
     trace_report_mycnn_2d = pickle.load(pickle_file)
        
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_myrescnn_2d.pkl', 'rb') as pickle_file:
     trace_report_myrescnn_2d = pickle.load(pickle_file)
        
        


plt.rcParams['ytick.labelsize'] = 20  # Font size for ytick labels
plt.style.use('classic')

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Surface', 'Noise']
variables = ['Scat(M1)', 'Scat(M2)', 'Scat(M3)', 
             'Scat(M4)', 'Scat(M5)', 'Scat(M6)',
             
             'Scat+Man(M1)','Scat+Man(M2)','Scat+Man(M3)',
             'Scat+Man(M4)','Scat+Man(M5)','Scat+Man(M6)',
             
             'Tsf(M1)', 'Tsf(M2)', 'Tsf(M3)',
             'Tsf(M4)', 'Tsf(M5)', 'Tsf(M6)',
             
             'Tsf+Man(M1)', 'Tsf+Man(M2)', 'Tsf+Man(M3)',
             'Tsf+Man(M4)', 'Tsf+Man(M5)', 'Tsf+Man(M6)',
             
             'Phy(M1)', 'Phy(M2)', 'Phy(M3)',
             'Phy(M4)', 'Phy(M5)', 'Phy(M6)',
             
             'Phy+Man(M1)', 'Phy+Man(M2)', 'Phy+Man(M3)',
             'Phy+Man(M4)', 'Phy+Man(M5)', 'Phy+Man(M6)',
             
            'Phy+Tsf(M1)', 'Phy+Tsf(M2)', 'Phy+Tsf(M3)',
             'Phy+Tsf(M4)', 'Phy+Tsf(M5)', 'Phy+Tsf(M6)',
             
             'Phy+Tsf+Man(M1)', 'Phy+Tsf+Man(M2)', 'Phy+Tsf+Man(M3)',
             'Phy+Tsf+Man(M4)', 'Phy+Tsf+Man(M5)', 'Phy+Tsf+Man(M6)',
            ]

# Creating a 2D array of values for each class and variable (Assuming these are defined elsewhere in your code)
# Set rc parameters for font size



# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model6).loc['precision'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_scat_man_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model6).loc['precision'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model6).loc['precision'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model6).loc['precision'].values[[0,1,3,2]],

    
    pd.DataFrame(trace_report_phy_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model6).loc['precision'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model6).loc['precision'].values[[0,1,3,2]],

    
    pd.DataFrame(trace_report_phy_tsf_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['precision'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['precision'].values[[0,1,3,2]]
    
])

values_recall = np.array([
        pd.DataFrame(trace_report_scat_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_model6).loc['recall'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_scat_man_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model6).loc['recall'].values[[0,1,3,2]],
    
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_model6).loc['recall'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model6).loc['recall'].values[[0,1,3,2]],
    

    
    pd.DataFrame(trace_report_phy_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_model6).loc['recall'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model6).loc['recall'].values[[0,1,3,2]],

    pd.DataFrame(trace_report_phy_tsf_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['recall'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['recall'].values[[0,1,3,2]],
    

])

values_accuracy = np.array([
    
    [pd.DataFrame(trace_report_scat_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_scat_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model6)['accuracy'].values[0]],
    
    
    
    
    [pd.DataFrame(trace_report_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_phy_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model6)['accuracy'].values[0]],
])



# Set rc parameters for font size
plt.rcParams['ytick.labelsize'] = 20

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(18, 15), facecolor = 'white')

# Define parameters for bar plots
bar_width = 0.8
bar_positions = np.linspace(0, 120, len(classes))        #np.arange(len(classes)) - 1
acc_bar_positions = np.linspace(0, 144, len(variables)) #np.arange(len(variables)) - 1

# Define specific colors for each model
#model_colors = ['#008080', '#4169E1', '#DC143C', 'brown']

model_colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf',
 '#a65628', '#984ea3', '#999999', '#e41a1c']

# Define patterns for each feature group
patterns = ['o', '/', '.','-' , '*','|']

# Define labels for subplots
sub_labels = ['(a)', '(b)', '(c)']

# Function to get color based on model
def get_pattern(variable):
    if 'M1' in variable:
        return patterns[0]
    elif 'M2' in variable:
        return patterns[1]
    elif 'M3' in variable:
        return patterns[2]
    elif 'M4' in variable:
        return patterns[3]
    elif 'M5' in variable:
        return patterns[4]
    elif 'M6' in variable:
        return patterns[5]
    else:
        return '#000000'  # default color if no match

# Function to get pattern based on feature set
def get_model_color(variable):
    if 'Scat' in variable and 'Man' not in variable:
        return model_colors[0]
    elif 'Scat+Man' in variable:
        return model_colors[1]
    elif 'Tsf' in variable  and 'Phy' not in variable and 'Man' not in variable:
        return model_colors[2]
    elif 'Tsf+Man' in variable and 'Phy' not in variable:
        return model_colors[3]
    elif 'Phy' in variable and 'Tsf' not in variable and 'Man' not in variable:
        return model_colors[4]
    elif 'Phy+Man' in variable and 'Tsf' not in variable:
        return model_colors[5]
    elif 'Phy+Tsf' in variable and 'Man' not in variable:
        return model_colors[6]
    elif 'Phy+Tsf+Man' in variable:
        return model_colors[7]
    else:
        return 'pink'  # default pattern if no match

# Iterate over each subplot
for idx, (ax, values, ylabel, title, label) in enumerate(zip(axes, [values_precision, values_recall, values_accuracy],
                                     ['Precision', 'Recall', 'Accuracy'],
                                     ['Precision', 'Recall', 'Accuracy'], sub_labels)):

    for i, var in enumerate(variables):
        pattern = get_pattern(var)
        color = get_model_color(var)
        if title == 'Accuracy':
            ax.bar(acc_bar_positions[i], values[i, 0]*100, width=bar_width + 0.9, label=var, color=color,edgecolor='black', linewidth=2, hatch=pattern)
        
        else:
            ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, align = 'edge',label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
            ax.set_xlabel('Class', fontsize=25)
    ax.set_xticks(bar_positions + (len(variables) - 1) * bar_width / 2)
    ax.set_xticklabels(classes, fontsize=25)
    
    ax.set_ylabel(ylabel, fontsize= 25)
    ax.set_ylim(55, 95)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    #for i, var in enumerate(variables):
    #    for j, value in enumerate(values[i, :]):
     #       if title != 'Accuracy':
                #ax.text(bar_positions[j] + i * bar_width, value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                #        fontsize= 10)
      #      else:
                #ax.text(acc_bar_positions[i], value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                 #       fontsize=20)

    #ax.set_title(title, fontsize=30)

    if title == 'Accuracy':
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_ylim(65, 92)
        ax.set_xlabel('Features', fontsize= 25)
    # Add subplot label
    ax.text(0.01, 0.9, label, transform=ax.transAxes, fontsize=20)

    
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, variables, loc='upper center', ncol=8, bbox_to_anchor=(0.5, 1.12), fontsize=14, frameon=False)

plt.grid(axis='y', linestyle='--', alpha=0.7)
#fig.suptitle("Trace wise results", fontsize=30)
#plt.legend(fontsize=12, ncol=8, loc='lower right', facecolor = 'white')
plt.tight_layout()
plt.savefig('../figures/cml_features_model_performance_comparisons.png', dpi = 300)
plt.show()

# %%
## Deep Learning
        
## MyCNN 1D
with open('../results/trace_report_quakexnet_1d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_1d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/trace_report_quakexnet_2d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_2d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/trace_report_seismiccnn_1d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_1d = pickle.load(pickle_file)
        
        
## MyCNN 1D
with open('../results/trace_report_seismiccnn_2d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_2d = pickle.load(pickle_file)
        
        


plt.rcParams['ytick.labelsize'] = 20  # Font size for ytick labels
plt.style.use('classic')

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Surface', 'Noise']
variables = ['seismiccnn_1d',
             'seismiccnn_2d',
             'quakexnet_1d',
             ''
            ]

# Creating a 2D array of values for each class and variable (Assuming these are defined elsewhere in your code)
# Set rc parameters for font size



# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_quakexnet_1d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_2d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_seismiccnn_1d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_seismiccnn_2d).loc['precision'].values[[0,1,3,2]],

    
])
# Out:
# {'0.0': {'precision': 0.8939393939393939,
#   'recall': 0.9163326653306614,
#   'f1-score': 0.9049975259772389,
#   'support': 1996},
#  '1.0': {'precision': 0.9298913043478261,
#   'recall': 0.8593671521848317,
#   'f1-score': 0.8932393630905769,
#   'support': 1991},
#  '2.0': {'precision': 0.9995,
#   'recall': 0.9950223992035838,
#   'f1-score': 0.9972561736093789,
#   'support': 2009},
#  '3.0': {'precision': 0.8941463414634147,
#   'recall': 0.9448453608247422,
#   'f1-score': 0.918796992481203,
#   'support': 1940},
#  'accuracy': 0.9289314516129032,
#  'macro avg': {'precision': 0.9293692599376587,
#   'recall': 0.9288918943859548,
#   'f1-score': 0.9285725137895995,
#   'support': 7936},
#  'weighted avg': {'precision': 0.9297323613531472,
#   'recall': 0.9289314516129032,
#   'f1-score': 0.9287762666278583,
#   'support': 7936}}

# %% [markdown]
# ## Plotting the performance of deep learning models on validation dataset (2000 traces/class)

# %%
## Deep Learning
        
## MyCNN 1D
with open('../results/trace_report_quakexnet_1d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_1d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/trace_report_quakexnet_2d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_2d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/trace_report_seismiccnn_1d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_1d = pickle.load(pickle_file)
        
        
## MyCNN 1D
with open('../results/trace_report_seismiccnn_2d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_2d = pickle.load(pickle_file)
        
        


plt.rcParams['ytick.labelsize'] = 20  # Font size for ytick labels
plt.style.use('classic')

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Surface', 'Noise']
variables = ['quakexnet_1d',
             'quakexnet_2d',
             'seismiccnn_1d',
             'seismiccnn_2d'
            ]

# Creating a 2D array of values for each class and variable (Assuming these are defined elsewhere in your code)
# Set rc parameters for font size



# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_quakexnet_1d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_2d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_seismiccnn_1d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_seismiccnn_2d).loc['precision'].values[[0,1,3,2]],

    
])

values_recall = np.array([  
    pd.DataFrame(trace_report_quakexnet_1d).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_2d).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_seismiccnn_1d).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_1d).loc['recall'].values[[0,1,3,2]],

    

])

values_accuracy = np.array([ 
    
    [pd.DataFrame(trace_report_quakexnet_1d)['accuracy'].values[0]],
      [pd.DataFrame(trace_report_quakexnet_2d)['accuracy'].values[0]],
      [pd.DataFrame(trace_report_seismiccnn_1d)['accuracy'].values[0]],
      [pd.DataFrame(trace_report_seismiccnn_2d)['accuracy'].values[0]],
])





# Set rc parameters for font size
plt.rcParams['ytick.labelsize'] = 20

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(15, 15), facecolor = 'white')

# Define parameters for bar plots
bar_width = 0.2
bar_positions = np.linspace(0, 5, len(classes))        #np.arange(len(classes)) - 1
acc_bar_positions = np.linspace(0, 20, len(variables)) #np.arange(len(variables)) - 1

# Define specific colors for each model
#model_colors = ['#008080', '#4169E1', '#DC143C', 'brown']

model_colors = ['#dede00', '#0173b2', '#fdb462', '#8dd3c7']

# Define patterns for each feature group
patterns = ['o', '/', '.','-' , '*','|']

# Define labels for subplots
sub_labels = ['(a)', '(b)', '(c)']




# Iterate over each subplot
for idx, (ax, values, ylabel, title, label) in enumerate(zip(axes, [values_precision, values_recall, values_accuracy],
                                     ['Precision', 'Recall', 'Accuracy'],
                                     ['Precision', 'Recall', 'Accuracy'], sub_labels)):

    for i, var in enumerate(variables):
        pattern = get_pattern(var)
        color = model_colors[i]
        if title == 'Accuracy':
            ax.bar(acc_bar_positions[i], values[i, 0]*100, width=bar_width + 0.5, label=var, color=color,edgecolor='black', linewidth=2, hatch=pattern)
        
        else:
            ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, align = 'edge',label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
            ax.set_xlabel('Class', fontsize=20)
    ax.set_xticks(bar_positions + (len(variables) - 1) * bar_width / 2)
    ax.set_xticklabels(classes, fontsize=20)
    
    ax.set_ylabel(ylabel, fontsize= 20)
    ax.set_ylim(70, 100)
    ax.grid(axis='y', linestyle='--', alpha=0.7)

    #for i, var in enumerate(variables):
    #    for j, value in enumerate(values[i, :]):
     #       if title != 'Accuracy':
                #ax.text(bar_positions[j] + i * bar_width, value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                #        fontsize= 10)
      #      else:
                #ax.text(acc_bar_positions[i], value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                 #       fontsize=20)

    #ax.set_title(title, fontsize=30)

    if title == 'Accuracy':
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_ylim(65, 100)
        ax.set_xlabel('Models', fontsize= 20)
    # Add subplot label
    ax.text(0.01, 0.9, label, transform=ax.transAxes, fontsize=20)

    
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, variables, loc='upper center', ncol=8, bbox_to_anchor=(0.5, 1.05), fontsize= 20, frameon=False)

plt.grid(axis='y', linestyle='--', alpha=0.7)
#fig.suptitle("Trace wise results", fontsize=30)
#plt.legend(fontsize=12, ncol=8, loc='lower right', facecolor = 'white')
plt.tight_layout()
plt.savefig('../figures/cml_features_model_performance_comparisons.png', dpi = 300)
plt.show()
# Out:
# /tmp/ipykernel_2728011/3433012027.py:108: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "#0". Passing invalid values is deprecated since 3.4 and will become an error in 3.11.
#   ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, align = 'edge',label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
# /tmp/ipykernel_2728011/3433012027.py:108: MatplotlibDeprecationWarning: hatch must consist of a string of "*+-./OX\ox|" or None, but found the following invalid values "#0". Passing invalid values is deprecated since 3.4 and will become an error in 3.11.
#   ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, align = 'edge',label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
# ...

# %% [markdown]
# ## Plotting deep learning models with machine learning models

# %%
filename2 = 'P_10_30_F_05_15_50'



# Save to a file
with open('../results/common_test_report_scat_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model2 = pickle.load(pickle_file)

     
    

# Save to a file
with open('../results/common_test_report_scat_man_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model2 = pickle.load(pickle_file)


# Save to a file
with open('../results/common_test_report_phy_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model2 = pickle.load(pickle_file)      


        
# Save to a file
with open('../results/common_test_report_phy_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model2 = pickle.load(pickle_file)      
        

        
    
# Save to a file
with open('../results/common_test_report_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model2 = pickle.load(pickle_file)


# Save to a file
with open('../results/common_test_report_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model2 = pickle.load(pickle_file)
  
        
with open('../results/common_test_report_phy_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model2 = pickle.load(pickle_file)
            

with open('../results/common_test_report_phy_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model2 = pickle.load(pickle_file)
        

        
        
## Deep Learning
        
## MyCNN 1D
with open('../results/common_test_report_SeismicCNN_1d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_1d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/common_test_report_SeismicCNN_2d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_2d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/common_test_report_QuakeXNet_1d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_1d = pickle.load(pickle_file)
        
        
## MyCNN 1D
with open('../results/common_test_report_QuakeXNet_2d.pkl', 'rb') as pickle_file:
     trace_report_quakexnet_2d = pickle.load(pickle_file)







plt.style.use('default')
plt.rcParams['ytick.labelsize'] = 15  # Font size for ytick labels

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Surface', 'Noise']


variables = [ # ml models
              'Scat(M2)',         
              'Scat+Man(M2)',            
              'Tsf(M2)',              
              'Tsf+Man(M2)', 
              'Phy(M2)',
              'Phy+Man(M2)', 
              'Phy+Tsf(M2)', 
              'Phy+Tsf+Man(M2)', 
             
             # deep learning models
                'SeismicCNN(1D)',
                'SeismicCNN(2D)',
                'QuakeXNet(1D)',
                'QuakeXNet(2D)'
            ]


# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_seismiccnn_1d).loc['precision'].values[[0,1,3,2]], 
    pd.DataFrame(trace_report_seismiccnn_2d).loc['precision'].values[[0,1,3,2]], 
    pd.DataFrame(trace_report_quakexnet_1d).loc['precision'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_2d).loc['precision'].values[[0,1,3,2]],])
    
    
    
# Creating a 2D array of values for each class and variable
values_recall = np.array([
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[[0,1,3,2]],
    
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[[0,1,3,2]],
    
    
    pd.DataFrame(trace_report_seismiccnn_1d).loc['recall'].values[[0,1,3,2]], 
    pd.DataFrame(trace_report_seismiccnn_2d).loc['recall'].values[[0,1,3,2]], 
    pd.DataFrame(trace_report_quakexnet_1d).loc['recall'].values[[0,1,3,2]],
    pd.DataFrame(trace_report_quakexnet_2d).loc['recall'].values[[0,1,3,2]], 
])



# Creating a 2D array of values for each class and variable
values_accuracy = np.array([
    pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0],
    
    
    pd.DataFrame(trace_report_seismiccnn_1d)['accuracy'].values[0], 
    pd.DataFrame(trace_report_seismiccnn_2d)['accuracy'].values[0], 
    pd.DataFrame(trace_report_quakexnet_1d)['accuracy'].values[0],
    pd.DataFrame(trace_report_quakexnet_2d)['accuracy'].values[0], 
])



# Sample data placeholders
num_models = 12
num_classes = 4
variables = [ # ml models
              'Scat(M2)',         
              'Scat+Man(M2)',            
              'Tsf(M2)',              
              'Tsf+Man(M2)', 
              'Phy(M2)',
              'Phy+Man(M2)', 
              'Phy+Tsf(M2)', 
              'Phy+Tsf+Man(M2)', 
             
             # deep learning models
                'SeismicCNN(1D)',
                'SeismicCNN(2D)',
                'QuakeXNet(1D)',
                'QuakeXNet(2D)'
            ]



classes = ['Earthquake', 'Explosion', 'Surface','Noise']


# Define a color-blind-friendly color palette
colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf',
 '#a65628', '#984ea3', '#999999', '#e41a1c',
 '#dede00', '#0173b2', '#fdb462', '#8dd3c7']

# Deep learning models
deep_learning_models = ['SeismicCNN(1D)', 'SeismicCNN(2D)', 'QuakeXNet(1D)', 'QuakeXNet(2D)']

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex=False)
bar_width = 0.8 / num_models
index = np.arange(num_classes)


# Plotting function
def plot_metric(ax, values, ylabel, ylim):
    for i, model in enumerate(variables):
        hatch = '//' if model in deep_learning_models else ''
        ax.bar(index + i * bar_width, values[i]*100, bar_width, label=model, color=colors[i], hatch=hatch)

    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_xticks(index + bar_width * (num_models - 1) / 2)
    ax.set_xticklabels(classes, fontsize=14)
    ax.grid(axis='y', linestyle='--', color='gray', alpha=0.7)
    ax.set_ylim(ylim)

# Plot Precision, Recall, Accuracy
plot_metric(axes[0], values_precision, 'Precision', (55, 100))
plot_metric(axes[1], values_recall, 'Recall', (55, 100))

# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[2].bar(i, values_accuracy[i]*100, color=colors[i], hatch=hatch)

axes[2].set_ylabel('Accuracy', fontsize=16)
axes[2].set_xticks(np.arange(len(variables)))
axes[2].set_xticklabels(variables, rotation=45, ha='right', fontsize=12)
axes[2].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
axes[2].set_ylim(65, 100)

# Add legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.05), fontsize=12, frameon=False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('../figures/cml_features_and_deep_learning_model_performance_comparisons.png', dpi=300)
plt.show()

# %% [markdown]
# ## Comparing the performance on the common test dataset

# %%
filename2 = 'P_10_30_F_05_15_50'
filename4 = 'P_10_100_F_05_15_50'
filename6 = 'P_50_100_F_05_15_50'

# Save to a file
with open('../results/common_test_report_phy_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model2 = pickle.load(pickle_file)    
        
# Save to a file
with open('../results/common_test_report_phy_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model4 = pickle.load(pickle_file)  
        
# Save to a file
with open('../results/common_test_report_phy_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model6 = pickle.load(pickle_file)

# %%
pd.DataFrame(trace_report_phy_man_model6)
# Out:
#                      0            1            2            3  accuracy  \
# precision     0.876000     0.884442     0.951856     0.840183  0.886961
# recall        0.855887     0.893380     0.899526     0.898876  0.886961
# f1-score      0.865827     0.888889     0.924951     0.868539  0.886961
# support    2047.000000  1979.000000  2110.000000  2047.000000  0.886961
#
#              macro avg  weighted avg
# precision     0.888120      0.888641
# recall        0.886917      0.886961
# f1-score      0.887051      0.887328
# support    8183.000000   8183.000000

# %%
pd.DataFrame(trace_report_quakexnet_2d)
# Out:
#                    0.0          1.0          2.0          3.0  accuracy  \
# precision     0.907463     0.904082     0.988431     0.896866  0.924269
# recall        0.921678     0.892246     0.989426     0.893703  0.924269
# f1-score      0.914515     0.898125     0.988928     0.895281  0.924269
# support    1979.000000  1986.000000  1986.000000  1985.000000  0.924269
#
#              macro avg  weighted avg
# precision     0.924210      0.924228
# recall        0.924263      0.924269
# f1-score      0.924212      0.924224
# support    7936.000000   7936.000000

# %% [markdown]
# ## Comparing the training times of different models

# %%
## Loading training times of deep learning models
with open('../results/model_training_time_seismiccnn_1d.pkl', 'rb') as pickle_file:
     mt_seismiccnn_1d = pickle.load(pickle_file)

with open('../results/model_training_time_seismiccnn_2d.pkl', 'rb') as pickle_file:
     mt_seismiccnn_2d = pickle.load(pickle_file)
        
with open('../results/model_training_time_quakexnet_1d.pkl', 'rb') as pickle_file:
     mt_quakexnet_1d = pickle.load(pickle_file)
        
with open('../results/model_training_time_quakexnet_2d.pkl', 'rb') as pickle_file:
     mt_quakexnet_2d = pickle.load(pickle_file)
        
# loading training times of machine learning models
with open('../results/model_training_time_phy_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_phy = pickle.load(pickle_file)
        
with open('../results/model_training_time_phy_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_phy_man = pickle.load(pickle_file)
        
        
with open('../results/model_training_time_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_tsf = pickle.load(pickle_file)
        
with open('../results/model_training_time_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_tsf_man = pickle.load(pickle_file)
        
        
with open('../results/model_training_time_phy_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_phy_tsf = pickle.load(pickle_file)
        
with open('../results/model_training_time_phy_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mt_phy_tsf_man = pickle.load(pickle_file)
        
with open('../results/model_training_time_scat_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     mt_scat = pickle.load(pickle_file)
        
with open('../results/model_training_time_scat_man_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     mt_scat_man = pickle.load(pickle_file)

# %%
## Loading model inference time(s)
## Loading training times of deep learning models
with open('../results/common_test_model_inference_time_per_sample_SeismicCNN_1d.pkl', 'rb') as pickle_file:
     mc_seismiccnn_1d = pickle.load(pickle_file)

with open('../results/common_test_model_inference_time_per_sample_SeismicCNN_2d.pkl', 'rb') as pickle_file:
     mc_seismiccnn_2d = pickle.load(pickle_file)
        
        
with open('../results/common_test_model_inference_time_per_sample_QuakeXNet_1d.pkl', 'rb') as pickle_file:
     mc_quakexnet_1d = pickle.load(pickle_file)

with open('../results/common_test_model_inference_time_per_sample_QuakeXNet_2d.pkl', 'rb') as pickle_file:
     mc_quakexnet_2d = pickle.load(pickle_file)
        
        
with open('../results/common_test_model_inference_time_per_sample_phy_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_phy = pickle.load(pickle_file)

with open('../results/common_test_model_inference_time_per_sample_phy_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_phy_man = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_tsf = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_tsf_man = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_phy_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_phy_tsf = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_phy_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     mc_phy_tsf_man = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_scat_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     mc_scat = pickle.load(pickle_file)
        
with open('../results/common_test_model_inference_time_per_sample_scat_man_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     mc_scat_man = pickle.load(pickle_file)

# %%
## Loading model inference time(s)
## Loading training times of deep learning models
with open('../results/station_day_classification_time_seismiccnn_1d.pkl', 'rb') as pickle_file:
     sd_seismiccnn_1d = pickle.load(pickle_file)

with open('../results/station_day_classification_time_seismiccnn_2d.pkl', 'rb') as pickle_file:
     sd_seismiccnn_2d = pickle.load(pickle_file)
        
        
with open('../results/station_day_classification_time_quakexnet_1d.pkl', 'rb') as pickle_file:
     sd_quakexnet_1d = pickle.load(pickle_file)

with open('../results/station_day_classification_time_quakexnet_2d.pkl', 'rb') as pickle_file:
     sd_quakexnet_2d = pickle.load(pickle_file)
        
        
with open('../results/station_day_classification_time_phy_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_phy = pickle.load(pickle_file)

with open('../results/station_day_classification_time_phy_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_phy_man = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_tsf = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_tsf_man = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_phy_tsf_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_phy_tsf = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_phy_tsf_man_P_10_30_F_05_15_50.pkl', 'rb') as pickle_file:
     sd_phy_tsf_man = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_scat_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     sd_scat = pickle.load(pickle_file)
        
with open('../results/station_day_classification_time_scat_man_P_10_30_F_0_15_50.pkl', 'rb') as pickle_file:
     sd_scat_man = pickle.load(pickle_file)

# %%
plt.style.use('default')
plt.rcParams['ytick.labelsize'] = 15  # Font size for ytick labels


# Sample data placeholders
num_models = 12
num_classes = 4
variables = [ # ml models
              'Scat(M2)',         
              'Scat+Man(M2)',            
              'Tsf(M2)',              
              'Tsf+Man(M2)', 
              'Phy(M2)',
              'Phy+Man(M2)', 
              'Phy+Tsf(M2)', 
              'Phy+Tsf+Man(M2)', 
             
             # deep learning models
                'SeismicCNN(1D)',
                'SeismicCNN(2D)',
                'QuakeXNet(1D)',
                'QuakeXNet(2D)'
            ]


values_mt = [mt_scat,
         mt_scat_man,
         mt_tsf,
         mt_tsf_man, 
         mt_phy,
         mt_phy_man, 
         mt_phy_tsf, 
         mt_phy_tsf_man, 
         mt_seismiccnn_1d,
         mt_seismiccnn_2d, 
         mt_quakexnet_1d, 
         mt_quakexnet_2d]

values_mc = [mc_scat,
         mc_scat_man,
         mc_tsf,
         mc_tsf_man, 
         mc_phy,
         mc_phy_man, 
         mc_phy_tsf, 
         mc_phy_tsf_man, 
         mc_seismiccnn_1d,
         mc_seismiccnn_2d, 
         mc_quakexnet_1d, 
         mc_quakexnet_2d]


values_ss = [436,
         415,
         291,
         284, 
         289,
         274, 
         289, 
         291, 
         40.9,
         7.96, 
         2.65, 
         0.306]

classes = ['Earthquake', 'Explosion', 'Surface','Noise']


# Define a color-blind-friendly color palette
colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf',
 '#a65628', '#984ea3', '#999999', '#e41a1c',
 '#dede00', '#0173b2', '#fdb462', '#8dd3c7']

# Deep learning models
deep_learning_models = ['SeismicCNN(1D)', 'SeismicCNN(2D)', 'QuakeXNet(1D)', 'QuakeXNet(2D)']

# Create subplots
fig, axes = plt.subplots(3, 1, figsize=(12, 10), sharex= True)
bar_width = 0.8 / num_models
index = np.arange(num_classes)


# Plotting function
def plot_metric(ax, values, ylabel, ylim):
    for i, model in enumerate(variables):
        hatch = '//' if model in deep_learning_models else ''
        ax.bar(index + i * bar_width, values[i], bar_width, label=model, color=colors[i], hatch=hatch)

    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_xticks(index + bar_width * (num_models - 1) / 2)
    ax.set_xticklabels(classes, fontsize=14)
    ax.grid(axis='y', linestyle='--', color='gray', alpha=0.7)
    ax.set_ylim(ylim)

# Plot Precision, Recall, Accuracy


# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[0].bar(i, values_mt[i], color=colors[i], hatch=hatch)
 
axes[0].set_ylabel('Model training time(s)', fontsize=16)
axes[0].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
axes[0].set_ylim(50, 500)


# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[1].bar(i, values_mc[i], color=colors[i], hatch=hatch)
 
axes[1].set_ylabel('Model inference time \n per sample(s)', fontsize=16)
axes[1].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
axes[1].set_ylim(0, 15**(-3))


    
# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[2].bar(i, values_ss[i], color=colors[i], hatch=hatch)

axes[2].set_ylabel('Trained Model Sizes (MB)', fontsize=16)
axes[2].set_xticks(np.arange(len(variables)))
axes[2].set_xticklabels(variables, rotation=45, ha='right', fontsize=12)
axes[2].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
axes[2].set_ylim(0, 500)

# Add legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.05), fontsize=12, frameon=False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('../figures/cml_features_and_deep_learning_model_performance_comparisons.png', dpi=300)
plt.show()

# %%
plt.style.use('default')
plt.rcParams['ytick.labelsize'] = 15  # Font size for ytick labels


# Sample data placeholders
num_models = 12
num_classes = 4
variables = [ # ml models
              'Scat(M2)',         
              'Scat+Man(M2)',            
              'Tsf(M2)',              
              'Tsf+Man(M2)', 
              'Phy(M2)',
              'Phy+Man(M2)', 
              'Phy+Tsf(M2)', 
              'Phy+Tsf+Man(M2)', 
             
             # deep learning models
                'SeismicCNN(1D)',
                'SeismicCNN(2D)',
                'QuakeXNet(1D)',
                'QuakeXNet(2D)'
            ]




values_sd = [sd_scat,
         sd_scat_man,
         sd_tsf,
         sd_tsf_man, 
         sd_phy,
         sd_phy_man, 
         sd_phy_tsf, 
         sd_phy_tsf_man, 
         sd_seismiccnn_1d,
         sd_seismiccnn_2d, 
         sd_quakexnet_1d, 
         sd_quakexnet_2d]


values_ss = [436,
         415,
         291,
         284, 
         289,
         274, 
         289, 
         291, 
         40.9,
         7.96, 
         2.65, 
         0.306]

classes = ['Earthquake', 'Explosion', 'Surface','Noise']


# Define a color-blind-friendly color palette
colors = ['#377eb8', '#ff7f00', '#4daf4a', '#f781bf',
 '#a65628', '#984ea3', '#999999', '#e41a1c',
 '#dede00', '#0173b2', '#fdb462', '#8dd3c7']

# Deep learning models
deep_learning_models = ['SeismicCNN(1D)', 'SeismicCNN(2D)', 'QuakeXNet(1D)', 'QuakeXNet(2D)']

# Create subplots
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex= True)
bar_width = 0.8 / num_models
index = np.arange(num_classes)


# Plotting function
def plot_metric(ax, values, ylabel, ylim):
    for i, model in enumerate(variables):
        hatch = '//' if model in deep_learning_models else ''
        ax.bar(index + i * bar_width, values[i], bar_width, label=model, color=colors[i], hatch=hatch)

    ax.set_ylabel(ylabel, fontsize=16)
    ax.set_xticks(index + bar_width * (num_models - 1) / 2)
    ax.set_xticklabels(classes, fontsize=14)
    ax.grid(axis='y', linestyle='--', color='gray', alpha=0.7)
    ax.set_ylim(ylim)

# Plot Precision, Recall, Accuracy


# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[0].bar(i, values_sd[i], color=colors[i], hatch=hatch)
 
axes[0].set_ylabel('Station day classification time(s)', fontsize=16)
axes[0].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
#axes[0].set_ylim(50, 500)
axes[0].set_yscale('log')


    
# Accuracy Plot
for i, model in enumerate(variables):
    hatch = '//' if model in deep_learning_models else ''
    axes[1].bar(i, values_ss[i], color=colors[i], hatch=hatch)

axes[1].set_ylabel('Trained Model Sizes (MB)', fontsize=16)
axes[1].set_xticks(np.arange(len(variables)))
axes[1].set_xticklabels(variables, rotation=45, ha='right', fontsize=12)
axes[1].grid(axis='y', linestyle='--', color='gray', alpha=0.7)
#axes[2].set_ylim(0, 500)
axes[1].set_yscale('log')

# Add legend
handles, labels = axes[0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper center', ncol=3, bbox_to_anchor=(0.5, 1.05), fontsize=12, frameon=False)

# Adjust layout
plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.savefig('../figures/cml_features_and_deep_learning_model_performance_comparisons.png', dpi=300)
plt.show()
