# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from glob import glob
import pickle

import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
filename1 = 'P_10_30_F_1_10_50'
filename2 = 'P_10_30_F_05_15_50'

filename3 = 'P_10_100_F_1_10_50'
filename4 = 'P_10_100_F_05_15_50'

filename5 = 'P_50_100_F_1_10_50'
filename6 = 'P_50_100_F_05_15_50'




## scatnet results
# Save to a file
with open('../results/balanced_trace_report_scat_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_10_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model4 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model5 = pickle.load(pickle_file)
        
        
# Save to a file
with open('../results/balanced_trace_report_scat_'+'P_50_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_model6 = pickle.load(pickle_file)
        
        
        
        
        
        
        
        
## scatnet results
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model1 = pickle.load(pickle_file)
        
        
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_10_30_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_10_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_scat_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model5 = pickle.load(pickle_file)     

# Save to a file
with open('../results/balanced_trace_report_scat_man_'+'P_50_100_F_0_15_50'+'.pkl', 'rb') as pickle_file:
     trace_report_scat_man_model6 = pickle.load(pickle_file)
        
        
                  


## Physical results        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model1 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model2 = pickle.load(pickle_file)      
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model3 = pickle.load(pickle_file)
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model4 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_model6 = pickle.load(pickle_file)
 


        
## Physical+Manual results        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model1 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model2 = pickle.load(pickle_file)      
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model3 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model5 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_phy_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_man_model6 = pickle.load(pickle_file)
        
        
        
        
        
## Tsfel results
# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model4 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_model6 = pickle.load(pickle_file)
     
    
    
    
    
    
    
## Tsfel + Man results
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model1 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model2 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model3 = pickle.load(pickle_file)
        
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model4 = pickle.load(pickle_file)    
        
# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model5 = pickle.load(pickle_file)

# Save to a file
with open('../results/balanced_trace_report_tsf_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_tsf_man_model6 = pickle.load(pickle_file)      
        
    
    
    
    
        
## Tsfel + Physical results
with open('../results/balanced_trace_report_phy_tsf_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model1 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model2 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model3 = pickle.load(pickle_file)

with open('../results/balanced_trace_report_phy_tsf_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model4 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model5 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_model6 = pickle.load(pickle_file)
        
        
        
## Tsfel + Physical + Manual
with open('../results/balanced_trace_report_phy_tsf_man_'+filename1+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model1 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename2+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model2 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename3+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model3 = pickle.load(pickle_file)

with open('../results/balanced_trace_report_phy_tsf_man_'+filename4+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model4 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename5+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model5 = pickle.load(pickle_file)
        
with open('../results/balanced_trace_report_phy_tsf_man_'+filename6+'.pkl', 'rb') as pickle_file:
     trace_report_phy_tsf_man_model6 = pickle.load(pickle_file)
        
        
## Deep Learning
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_mycnn_1d.pkl', 'rb') as pickle_file:
     trace_report_mycnn_1d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_seismiccnn_2d.pkl', 'rb') as pickle_file:
     trace_report_seismiccnn_2d = pickle.load(pickle_file)
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_mycnn_2d.pkl', 'rb') as pickle_file:
     trace_report_mycnn_2d = pickle.load(pickle_file)
        
        
## MyCNN 1D
with open('../results/balanced_trace_report_deep_learning_myrescnn_2d.pkl', 'rb') as pickle_file:
     trace_report_myrescnn_2d = pickle.load(pickle_file)

# %%
plt.rcParams['ytick.labelsize'] = 20  # Font size for ytick labels


# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Noise', 'Surface']
variables = ['Scat(M1)', 'Scat(M2)', 'Scat(M3)', 
             'Scat+Man(M1)','Scat+Man(M2)','Scat+Man(M3)',
             'Tsf(M1)', 'Tsf(M2)', 'Tsf(M3)',
             'Tsf+Man(M1)', 'Tsf+Man(M2)', 'Tsf+Man(M3)',
             'Phy(M1)', 'Phy(M2)', 'Phy(M3)', 
             'Phy+Man(M1)', 'Phy+Man(M2)', 'Phy+Man(M3)',
            'Phy+Tsf(M1)', 'Phy+Tsf(M2)', 'Phy+Tsf(M3)',
             'Phy+Tsf+Man(M1)', 'Phy+Tsf+Man(M2)', 'Phy+Tsf+Man(M3)']

# Creating a 2D array of values for each class and variable (Assuming these are defined elsewhere in your code)
# Set rc parameters for font size



# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_scat_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['precision'].values[0:4],
    

    
    pd.DataFrame(trace_report_phy_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['precision'].values[0:4],

    pd.DataFrame(trace_report_phy_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['precision'].values[0:4]
    
])

values_recall = np.array([
        pd.DataFrame(trace_report_scat_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['recall'].values[0:4],
    
    pd.DataFrame(trace_report_scat_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['recall'].values[0:4],
    
    pd.DataFrame(trace_report_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['recall'].values[0:4],
    

    
    pd.DataFrame(trace_report_phy_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['recall'].values[0:4],

    pd.DataFrame(trace_report_phy_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['recall'].values[0:4]

])

values_accuracy = np.array([
    
    [pd.DataFrame(trace_report_scat_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model3)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_scat_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model3)['accuracy'].values[0]],
    
    [pd.DataFrame(trace_report_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model3)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model3)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_phy_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model3)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model3)['accuracy'].values[0]],

    
    
    [pd.DataFrame(trace_report_phy_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model3)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_phy_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model3)['accuracy'].values[0]],
])



# Set rc parameters for font size
plt.rcParams['ytick.labelsize'] = 20

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(30, 24))

# Define parameters for bar plots
bar_width = 1 / (len(variables)+1)
bar_positions = np.arange(len(classes))
acc_bar_positions = np.arange(len(variables))

# Define specific colors for each model
#model_colors = ['#008080', '#4169E1', '#DC143C', 'brown']

model_colors = ['#1B4F72', '#D35400', '#1E8449', '#6C3483', '#148F77', '#566573', '#C0392B', '#5DADE2']

# Define patterns for each feature group
patterns = ['o', '/', '-','.' ]

# Define labels for subplots
sub_labels = ['(a)', '(b)', '(c)']

# Function to get color based on model
def get_pattern(variable):
    if 'M1' in variable:
        return patterns[0]
    elif 'M2' in variable:
        return patterns[1]
    elif 'M3' in variable:
        return patterns[2]
    else:
        return '#000000'  # default color if no match

# Function to get pattern based on feature set
def get_model_color(variable):
    if 'Scat' in variable and 'Man' not in variable:
        return model_colors[0]
    elif 'Scat+Man' in variable:
        return model_colors[1]
    elif 'Phy' in variable and 'Tsf' not in variable and 'Man' not in variable:
        return model_colors[2]
    elif 'Phy+Man' in variable and 'Tsf' not in variable:
        return model_colors[3]
    elif 'Tsf' in variable  and 'Phy' not in variable and 'Man' not in variable:
        return model_colors[4]
    elif 'Tsf+Man' in variable and 'Phy' not in variable:
        return model_colors[5]
    elif 'Phy+Tsf' in variable and 'Man' not in variable:
        return model_colors[6]
    elif 'Phy+Tsf+Man' in variable:
        return model_colors[7]
    else:
        return 'pink'  # default pattern if no match

# Iterate over each subplot
for idx, (ax, values, ylabel, title, label) in enumerate(zip(axes, [values_precision, values_recall, values_accuracy],
                                     ['Precision Values', 'Recall Values', 'Accuracy Values'],
                                     ['Precision', 'Recall', 'Accuracy'], sub_labels)):

    for i, var in enumerate(variables):
        pattern = get_pattern(var)
        color = get_model_color(var)
        if title == 'Accuracy':
            ax.bar(acc_bar_positions[i], values[i, 0]*100, width=bar_width+0.3, label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
        
        else:
            ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
            ax.set_xlabel('Class', fontsize=30)
    ax.set_xticks(bar_positions + (len(variables) - 1) * bar_width / 2)
    ax.set_xticklabels(classes, fontsize=30)
    
    ax.set_ylabel(ylabel, fontsize=30)
    ax.set_ylim(60, 98)

    for i, var in enumerate(variables):
        for j, value in enumerate(values[i, :]):
            if title != 'Accuracy':
                ax.text(bar_positions[j] + i * bar_width, value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                        fontsize= 12)
            else:
                ax.text(acc_bar_positions[i], value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                        fontsize=20)

    #ax.set_title(title, fontsize=30)

    if title == 'Accuracy':
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_ylim(70, 92)
        ax.set_xlabel('Features', fontsize=30)
    # Add subplot label
    ax.text(0.01, 0.9, label, transform=ax.transAxes, fontsize=20)

#fig.suptitle("Trace wise results", fontsize=30)
plt.legend(fontsize=20, ncol=8, loc='lower right')
plt.tight_layout()
plt.savefig('../figures/trace_wise_model_performance_comparisons.png')
plt.show()

# %%
plt.rcParams['ytick.labelsize'] = 20  # Font size for ytick labels
plt.style.use('classic')

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Noise', 'Surface']
variables = ['Scat(M1)', 'Scat(M2)', 'Scat(M3)', 
             'Scat(M4)', 'Scat(M5)', 'Scat(M6)',
             
             'Scat+Man(M1)','Scat+Man(M2)','Scat+Man(M3)',
             'Scat+Man(M4)','Scat+Man(M5)','Scat+Man(M6)',
             
             'Tsf(M1)', 'Tsf(M2)', 'Tsf(M3)',
             'Tsf(M4)', 'Tsf(M5)', 'Tsf(M6)',
             
             'Tsf+Man(M1)', 'Tsf+Man(M2)', 'Tsf+Man(M3)',
             'Tsf+Man(M4)', 'Tsf+Man(M5)', 'Tsf+Man(M6)',
             
             'Phy(M1)', 'Phy(M2)', 'Phy(M3)',
             'Phy(M4)', 'Phy(M5)', 'Phy(M6)',
             
             'Phy+Man(M1)', 'Phy+Man(M2)', 'Phy+Man(M3)',
             'Phy+Man(M4)', 'Phy+Man(M5)', 'Phy+Man(M6)',
             
            'Phy+Tsf(M1)', 'Phy+Tsf(M2)', 'Phy+Tsf(M3)',
             'Phy+Tsf(M4)', 'Phy+Tsf(M5)', 'Phy+Tsf(M6)',
             
             'Phy+Tsf+Man(M1)', 'Phy+Tsf+Man(M2)', 'Phy+Tsf+Man(M3)',
             'Phy+Tsf+Man(M4)', 'Phy+Tsf+Man(M5)', 'Phy+Tsf+Man(M6)',
            ]

# Creating a 2D array of values for each class and variable (Assuming these are defined elsewhere in your code)
# Set rc parameters for font size



# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model6).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_scat_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model6).loc['precision'].values[0:4],

    
    pd.DataFrame(trace_report_phy_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model6).loc['precision'].values[0:4],

    
    pd.DataFrame(trace_report_phy_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['precision'].values[0:4]
    
])

values_recall = np.array([
        pd.DataFrame(trace_report_scat_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_scat_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model6).loc['recall'].values[0:4],
    
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model6).loc['recall'].values[0:4],
    

    
    pd.DataFrame(trace_report_phy_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model6).loc['recall'].values[0:4],

    pd.DataFrame(trace_report_phy_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['recall'].values[0:4],
    

])

values_accuracy = np.array([
    
    [pd.DataFrame(trace_report_scat_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_scat_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model6)['accuracy'].values[0]],
    
    
    
    
    [pd.DataFrame(trace_report_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_phy_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model6)['accuracy'].values[0]],
])



# Set rc parameters for font size
plt.rcParams['ytick.labelsize'] = 20

# Set up the figure and axes
fig, axes = plt.subplots(3, 1, figsize=(18, 15), facecolor = 'white')

# Define parameters for bar plots
bar_width = 1 / (len(variables)+1) + 0.05
bar_positions = np.linspace(0, 3*len(classes), len(classes))        #np.arange(len(classes)) - 1
acc_bar_positions = np.linspace(0, 3*len(variables), len(variables)) #np.arange(len(variables)) - 1

# Define specific colors for each model
#model_colors = ['#008080', '#4169E1', '#DC143C', 'brown']

model_colors = ['#1B4F72', '#D35400', '#1E8449', '#6C3483', '#148F77', '#566573', '#C0392B', '#5DADE2']

# Define patterns for each feature group
patterns = ['o', '/', '.','-' , '*','|']

# Define labels for subplots
sub_labels = ['(a)', '(b)', '(c)']

# Function to get color based on model
def get_pattern(variable):
    if 'M1' in variable:
        return patterns[0]
    elif 'M2' in variable:
        return patterns[1]
    elif 'M3' in variable:
        return patterns[2]
    elif 'M4' in variable:
        return patterns[3]
    elif 'M5' in variable:
        return patterns[4]
    elif 'M6' in variable:
        return patterns[5]
    else:
        return '#000000'  # default color if no match

# Function to get pattern based on feature set
def get_model_color(variable):
    if 'Scat' in variable and 'Man' not in variable:
        return model_colors[0]
    elif 'Scat+Man' in variable:
        return model_colors[1]
    elif 'Phy' in variable and 'Tsf' not in variable and 'Man' not in variable:
        return model_colors[2]
    elif 'Phy+Man' in variable and 'Tsf' not in variable:
        return model_colors[3]
    elif 'Tsf' in variable  and 'Phy' not in variable and 'Man' not in variable:
        return model_colors[4]
    elif 'Tsf+Man' in variable and 'Phy' not in variable:
        return model_colors[5]
    elif 'Phy+Tsf' in variable and 'Man' not in variable:
        return model_colors[6]
    elif 'Phy+Tsf+Man' in variable:
        return model_colors[7]
    else:
        return 'pink'  # default pattern if no match

# Iterate over each subplot
for idx, (ax, values, ylabel, title, label) in enumerate(zip(axes, [values_precision, values_recall, values_accuracy],
                                     ['Precision Values', 'Recall Values', 'Accuracy Values'],
                                     ['Precision', 'Recall', 'Accuracy'], sub_labels)):

    for i, var in enumerate(variables):
        pattern = get_pattern(var)
        color = get_model_color(var)
        if title == 'Accuracy':
            ax.bar(acc_bar_positions[i], values[i, 0]*100, width=bar_width + 0.9, label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
        
        else:
            ax.bar(bar_positions + i * bar_width, values[i, :]*100, width=bar_width, label=var, color=color, edgecolor='black', linewidth=2, hatch=pattern)
            ax.set_xlabel('Class', fontsize=30)
    ax.set_xticks(bar_positions + (len(variables) - 1) * bar_width / 2)
    ax.set_xticklabels(classes, fontsize=30)
    
    ax.set_ylabel(ylabel, fontsize=30)
    ax.set_ylim(60, 98)

    #for i, var in enumerate(variables):
    #    for j, value in enumerate(values[i, :]):
     #       if title != 'Accuracy':
                #ax.text(bar_positions[j] + i * bar_width, value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                #        fontsize= 10)
      #      else:
                #ax.text(acc_bar_positions[i], value*100 + 0.01, f'{value*100:.0f}', ha='center', va='bottom',
                 #       fontsize=20)

    #ax.set_title(title, fontsize=30)

    if title == 'Accuracy':
        ax.set_xticks([])
        ax.set_xticklabels([])
        ax.set_ylim(55, 92)
        ax.set_xlabel('Features', fontsize=40)
    # Add subplot label
    ax.text(0.01, 0.9, label, transform=ax.transAxes, fontsize=20)

#fig.suptitle("Trace wise results", fontsize=30)
plt.legend(fontsize=12, ncol=8, loc='lower right', facecolor = 'white')
plt.tight_layout()
plt.savefig('../figures/cml_features_model_performance_comparisons.png', dpi = 300)
plt.show()

# %% [markdown]
# ## Plotting deep learning models with machine learning models

# %%
plt.style.use('default')
plt.rcParams['ytick.labelsize'] = 15  # Font size for ytick labels

# Sample data (replace with your actual data)
classes = ['Earthquake', 'Explosion', 'Noise', 'Surface']


variables = [ # ml models
              'Scat(M2)',         
              'Scat+Man(M2)',            
              'Tsf(M2)',              
              'Tsf+Man(M2)', 
              'Phy(M2)',
              'Phy+Man(M2)', 
              'Phy+Tsf(M2)', 
              'Phy+Tsf+Man(M2)', 
             
             # deep learning models
                'MyCNN_1d',
                'SeismicCNN_2d',
                'MyCNN_2d',
                'MyResCNN_2d'
            ]


# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_mycnn_1d).loc['precision'].values[0:4], 
    pd.DataFrame(trace_report_seismiccnn_2d).loc['precision'].values[0:4], 
    pd.DataFrame(trace_report_mycnn_2d).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_myrescnn_2d).loc['precision'].values[0:4], 
])
    
    
    
# Creating a 2D array of values for each class and variable
values_recall = np.array([
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[0:4],
    
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[0:4],
    
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[0:4],
    
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_mycnn_1d).loc['recall'].values[0:4], 
    pd.DataFrame(trace_report_seismiccnn_2d).loc['recall'].values[0:4], 
    pd.DataFrame(trace_report_mycnn_2d).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_myrescnn_2d).loc['recall'].values[0:4], 
])



# Creating a 2D array of values for each class and variable
values_accuracy = np.array([
    pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0],
    
    pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0],
    pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0],
    
    
    pd.DataFrame(trace_report_mycnn_1d)['accuracy'].values[0], 
    pd.DataFrame(trace_report_seismiccnn_2d)['accuracy'].values[0], 
    pd.DataFrame(trace_report_mycnn_2d)['accuracy'].values[0],
    pd.DataFrame(trace_report_myrescnn_2d)['accuracy'].values[0], 
])



num_models = 12
num_classes = 4



# Define a color-blind-friendly color palette (CUD palette or similar)
colors = sns.color_palette("colorblind", num_models)  # Seaborn color-blind-friendly palette

# Define which models are deep learning models
deep_learning_models = ['MyCNN_1d', 'SeismicCNN_2d', 'MyCNN_2d', 'MyResCNN_2d']

# Creating a 3x1 subplot
fig, axes = plt.subplots(3, 1, figsize=(15, 12), sharex=False)

# Define width of bars and position of tick labels
bar_width = 0.8 / num_models
index = np.arange(num_classes)

# Plot precision with hatches for deep learning models
for i, model in enumerate(variables):
    if model in deep_learning_models:
        # Add diagonal hatch for deep learning models
        axes[0].bar(index + i * bar_width, values_precision[i], bar_width, label=model, color=colors[i], hatch='//')
    else:
        # Regular bars for machine learning models
        axes[0].bar(index + i * bar_width, values_precision[i], bar_width, label=model, color=colors[i])
        
axes[0].set_ylabel('Precision', fontsize=20)
axes[0].set_xticks(index + bar_width * (num_models - 1) / 2)
axes[0].set_xticklabels(classes, rotation=0, ha='center', fontsize=15)
axes[0].legend(loc='upper left', bbox_to_anchor=(1, 1))
axes[0].set_ylim(0.7, 1)

# Plot recall with hatches for deep learning models
for i, model in enumerate(variables):
    if model in deep_learning_models:
        axes[1].bar(index + i * bar_width, values_recall[i], bar_width, label=model, color=colors[i], hatch='//')
    else:
        axes[1].bar(index + i * bar_width, values_recall[i], bar_width, label=model, color=colors[i])

axes[1].set_ylabel('Recall', fontsize=20)
axes[1].set_xticks(index + bar_width * (num_models - 1) / 2)
axes[1].set_xticklabels(classes, rotation=0, ha='center', fontsize=15)
#axes[1].legend(loc='upper left', bbox_to_anchor=(1, 1))
axes[1].set_ylim(0.7, 1)

# Plot accuracy with hatches for deep learning models
for i, model in enumerate(variables):
    if model in deep_learning_models:
        axes[2].bar(i, values_accuracy[i], color=colors[i], hatch='//')
    else:
        axes[2].bar(i, values_accuracy[i], color=colors[i])

axes[2].set_ylabel('Accuracy', fontsize=20)
axes[2].set_xticks(np.arange(len(variables)))
axes[2].set_xticklabels(variables, rotation=50, fontsize=15)
axes[2].set_ylim(0.7, 1)

# Adjust layout for better readability
plt.tight_layout()
plt.savefig('../figures/cml_features_and_deep_learning_model_performance_comparisons.png', dpi = 300)
plt.show()

# %% [markdown]
# ## Printing the best performing models for each case

# %%
# List of DataFrames
df_list = [
    pd.DataFrame(trace_report_scat_model2), pd.DataFrame(trace_report_scat_man_model2),
    pd.DataFrame(trace_report_tsf_model2), pd.DataFrame(trace_report_tsf_man_model2),
    pd.DataFrame(trace_report_phy_model2), pd.DataFrame(trace_report_phy_man_model2),
    pd.DataFrame(trace_report_phy_tsf_model2), pd.DataFrame(trace_report_phy_tsf_man_model2),
    pd.DataFrame(trace_report_mycnn_1d), pd.DataFrame(trace_report_seismiccnn_2d),
    pd.DataFrame(trace_report_mycnn_2d), pd.DataFrame(trace_report_myrescnn_2d)
]

# Model names
variables = [
    'Scat(M2)', 'Scat+Man(M2)', 'Tsf(M2)', 'Tsf+Man(M2)',
    'Phy(M2)', 'Phy+Man(M2)', 'Phy+Tsf(M2)', 'Phy+Tsf+Man(M2)', 
    'MyCNN_1d', 'SeismicCNN_2d', 'MyCNN_2d', 'MyResCNN_2d'
]

# Initialize dictionaries for precision, recall, and accuracy
precision_data = {'Earthquake': [], 'Explosion': [], 'Surface Event': [], 'Noise': []}
recall_data = {'Earthquake': [], 'Explosion': [], 'Surface Event': [], 'Noise': []}
accuracy_data = []

# Loop through each DataFrame to extract precision, recall, and accuracy
for df in df_list:
    for col in precision_data.keys():
        precision_data[col].append(np.around(df.loc['precision', col], 2))
        recall_data[col].append(np.around(df.loc['recall', col], 2))
    accuracy_data.append(np.around(df.loc['recall', 'accuracy'], 2))

# Create DataFrames for precision, recall, and accuracy
df_prec_models = pd.DataFrame(precision_data, index=variables)
df_rec_models = pd.DataFrame(recall_data, index=variables)
df_acc_models = pd.DataFrame({'Accuracy': accuracy_data}, index=variables)

# Function to highlight maximum values
def highlight_max(s):
    is_max = s == s.max()
    return ['font-weight: bold' if v else '' for v in is_max]

# Apply the highlighting function to precision, recall, and accuracy DataFrames
df_styled_prec = df_prec_models.style.apply(highlight_max)
df_styled_rec = df_rec_models.style.apply(highlight_max)
df_styled_acc = df_acc_models.style.apply(highlight_max)

# %%
df_styled_prec
# Out:
# <style type="text/css">
# #T_65a7f_row6_col2, #T_65a7f_row7_col2, #T_65a7f_row8_col1, #T_65a7f_row8_col3, #T_65a7f_row9_col0, #T_65a7f_row11_col2 {
#   font-weight: bold;
# }
# </style>
# <table id="T_65a7f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Earthquake</th>
#       <th class="col_heading level0 col1" >Explosion</th>
#       <th class="col_heading level0 col2" >Surface Event</th>
#       <th class="col_heading level0 col3" >Noise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_65a7f_level0_row0" class="row_heading level0 row0" >Scat(M2)</th>
#       <td id="T_65a7f_row0_col0" class="data row0 col0" >0.690000</td>
#       <td id="T_65a7f_row0_col1" class="data row0 col1" >0.730000</td>
#       <td id="T_65a7f_row0_col2" class="data row0 col2" >0.830000</td>
#       <td id="T_65a7f_row0_col3" class="data row0 col3" >0.780000</td>
#     </tr>
#     <tr>
# ...

# %%
df_styled_rec
# Out:
# <style type="text/css">
# #T_ef60b_row8_col2, #T_ef60b_row8_col3, #T_ef60b_row9_col2, #T_ef60b_row11_col0, #T_ef60b_row11_col1, #T_ef60b_row11_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ef60b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Earthquake</th>
#       <th class="col_heading level0 col1" >Explosion</th>
#       <th class="col_heading level0 col2" >Surface Event</th>
#       <th class="col_heading level0 col3" >Noise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef60b_level0_row0" class="row_heading level0 row0" >Scat(M2)</th>
#       <td id="T_ef60b_row0_col0" class="data row0 col0" >0.770000</td>
#       <td id="T_ef60b_row0_col1" class="data row0 col1" >0.660000</td>
#       <td id="T_ef60b_row0_col2" class="data row0 col2" >0.740000</td>
#       <td id="T_ef60b_row0_col3" class="data row0 col3" >0.860000</td>
#     </tr>
#     <tr>
# ...

# %%
df_styled_acc
# Out:
# <style type="text/css">
# #T_4463d_row9_col0, #T_4463d_row11_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_4463d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4463d_level0_row0" class="row_heading level0 row0" >Scat(M2)</th>
#       <td id="T_4463d_row0_col0" class="data row0 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_4463d_level0_row1" class="row_heading level0 row1" >Scat+Man(M2)</th>
#       <td id="T_4463d_row1_col0" class="data row1 col0" >0.780000</td>
#     </tr>
#     <tr>
#       <th id="T_4463d_level0_row2" class="row_heading level0 row2" >Tsf(M2)</th>
#       <td id="T_4463d_row2_col0" class="data row2 col0" >0.860000</td>
#     </tr>
#     <tr>
#       <th id="T_4463d_level0_row3" class="row_heading level0 row3" >Tsf+Man(M2)</th>
# ...

# %%
variables = ['Scat(M1)', 'Scat(M2)', 'Scat(M3)', 
             'Scat(M4)', 'Scat(M5)', 'Scat(M6)',
             
             'Scat+Man(M1)','Scat+Man(M2)','Scat+Man(M3)',
             'Scat+Man(M4)','Scat+Man(M5)','Scat+Man(M6)',
             
             'Tsf(M1)', 'Tsf(M2)', 'Tsf(M3)',
             'Tsf(M4)', 'Tsf(M5)', 'Tsf(M6)',
             
             'Tsf+Man(M1)', 'Tsf+Man(M2)', 'Tsf+Man(M3)',
             'Tsf+Man(M4)', 'Tsf+Man(M5)', 'Tsf+Man(M6)',
             
             'Phy(M1)', 'Phy(M2)', 'Phy(M3)',
             'Phy(M4)', 'Phy(M5)', 'Phy(M6)',
             
             'Phy+Man(M1)', 'Phy+Man(M2)', 'Phy+Man(M3)',
             'Phy+Man(M4)', 'Phy+Man(M5)', 'Phy+Man(M6)',
             
            'Phy+Tsf(M1)', 'Phy+Tsf(M2)', 'Phy+Tsf(M3)',
             'Phy+Tsf(M4)', 'Phy+Tsf(M5)', 'Phy+Tsf(M6)',
             
             'Phy+Tsf+Man(M1)', 'Phy+Tsf+Man(M2)', 'Phy+Tsf+Man(M3)',
             'Phy+Tsf+Man(M4)', 'Phy+Tsf+Man(M5)', 'Phy+Tsf+Man(M6)',
            ]


# Creating a 2D array of values for each class and variable
# Creating a 2D array of values for each class and variable
values_precision = np.array([
    pd.DataFrame(trace_report_scat_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_model6).loc['precision'].values[0:4],
    
    pd.DataFrame(trace_report_scat_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model6).loc['precision'].values[0:4],

    
    pd.DataFrame(trace_report_phy_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model6).loc['precision'].values[0:4],

    
    pd.DataFrame(trace_report_phy_tsf_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['precision'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['precision'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['precision'].values[0:4]
    
])



values_recall = np.array([
        pd.DataFrame(trace_report_scat_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_scat_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_scat_man_model6).loc['recall'].values[0:4],
    
    
    
    pd.DataFrame(trace_report_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_tsf_man_model6).loc['recall'].values[0:4],
    

    
    pd.DataFrame(trace_report_phy_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_man_model6).loc['recall'].values[0:4],

    pd.DataFrame(trace_report_phy_tsf_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_model6).loc['recall'].values[0:4],
    
    
    pd.DataFrame(trace_report_phy_tsf_man_model1).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model2).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model3).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model4).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model5).loc['recall'].values[0:4],
    pd.DataFrame(trace_report_phy_tsf_man_model6).loc['recall'].values[0:4],
    

])

values_accuracy = np.array([
    
    [pd.DataFrame(trace_report_scat_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_scat_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_scat_man_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_model6)['accuracy'].values[0]],
    
    
    
    
    [pd.DataFrame(trace_report_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_tsf_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_model6)['accuracy'].values[0]],
    
    
    
    [pd.DataFrame(trace_report_phy_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_man_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_model6)['accuracy'].values[0]],
    
    
    [pd.DataFrame(trace_report_phy_tsf_man_model1)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model2)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model3)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model4)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model5)['accuracy'].values[0]],
    [pd.DataFrame(trace_report_phy_tsf_man_model6)['accuracy'].values[0]],
])


df_prec_cml = pd.DataFrame(np.around(values_precision, 2), columns = ['Earthquake', 'Explosion', 'Surface Event' ,'Noise'], index = variables)
df_rec_cml = pd.DataFrame(np.around(values_recall, 2), columns = ['Earthquake', 'Explosion', 'Surface Event' ,'Noise'], index = variables)
df_acc_cml = pd.DataFrame(np.around(values_accuracy, 2), columns = ['Accuracy'], index = variables)


# Apply the highlighting function to precision, recall, and accuracy DataFrames
df_styled_prec_cml = df_prec_cml.style.apply(highlight_max)
df_styled_rec_cml = df_rec_cml.style.apply(highlight_max)
df_styled_acc_cml = df_acc_cml.style.apply(highlight_max)

# %%
df_styled_prec_cml
# Out:
# <style type="text/css">
# #T_8bf3b_row26_col2, #T_8bf3b_row30_col3, #T_8bf3b_row31_col0, #T_8bf3b_row31_col1, #T_8bf3b_row32_col2, #T_8bf3b_row33_col3, #T_8bf3b_row37_col3, #T_8bf3b_row42_col3, #T_8bf3b_row43_col1, #T_8bf3b_row43_col3 {
#   font-weight: bold;
# }
# </style>
# <table id="T_8bf3b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Earthquake</th>
#       <th class="col_heading level0 col1" >Explosion</th>
#       <th class="col_heading level0 col2" >Surface Event</th>
#       <th class="col_heading level0 col3" >Noise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bf3b_level0_row0" class="row_heading level0 row0" >Scat(M1)</th>
#       <td id="T_8bf3b_row0_col0" class="data row0 col0" >0.680000</td>
#       <td id="T_8bf3b_row0_col1" class="data row0 col1" >0.730000</td>
#       <td id="T_8bf3b_row0_col2" class="data row0 col2" >0.770000</td>
# ...

# %%
df_styled_rec_cml
# Out:
# <style type="text/css">
# #T_ce15d_row24_col2, #T_ce15d_row28_col2, #T_ce15d_row30_col2, #T_ce15d_row31_col2, #T_ce15d_row31_col3, #T_ce15d_row32_col1, #T_ce15d_row33_col1, #T_ce15d_row34_col1, #T_ce15d_row34_col2, #T_ce15d_row35_col1, #T_ce15d_row43_col0, #T_ce15d_row44_col1, #T_ce15d_row46_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_ce15d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Earthquake</th>
#       <th class="col_heading level0 col1" >Explosion</th>
#       <th class="col_heading level0 col2" >Surface Event</th>
#       <th class="col_heading level0 col3" >Noise</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce15d_level0_row0" class="row_heading level0 row0" >Scat(M1)</th>
#       <td id="T_ce15d_row0_col0" class="data row0 col0" >0.770000</td>
#       <td id="T_ce15d_row0_col1" class="data row0 col1" >0.640000</td>
# ...

# %%
df_styled_acc_cml
# Out:
# <style type="text/css">
# #T_c97b3_row30_col0, #T_c97b3_row31_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_c97b3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c97b3_level0_row0" class="row_heading level0 row0" >Scat(M1)</th>
#       <td id="T_c97b3_row0_col0" class="data row0 col0" >0.740000</td>
#     </tr>
#     <tr>
#       <th id="T_c97b3_level0_row1" class="row_heading level0 row1" >Scat(M2)</th>
#       <td id="T_c97b3_row1_col0" class="data row1 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_c97b3_level0_row2" class="row_heading level0 row2" >Scat(M3)</th>
#       <td id="T_c97b3_row2_col0" class="data row2 col0" >0.750000</td>
#     </tr>
#     <tr>
#       <th id="T_c97b3_level0_row3" class="row_heading level0 row3" >Scat(M4)</th>
# ...
